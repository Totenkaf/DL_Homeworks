# %% [markdown]
# ## Семинар 8: "Современные модели для NLP"

# %% [markdown]
# ФИО: Усцов Артем Алексеевич

# %% [markdown]
# ### На семинаре мы разберем [код трансфомера на pytorch](https://nlp.seas.harvard.edu/2018/04/03/attention.html)

# %% [markdown]
# ###  ДЗ [3 балла]

# %% [markdown]
# Обратите внимание, что в этой работе вам потребуется скачать модель весом ~150MB, также ее вычисление занимает определенное время, так что рекомендуется считать эту задачу на [google colab](https://colab.research.google.com/).

# %%
# !pip install sentencepiece
# !pip install --upgrade transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 5.1 MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.97

# %%
import torch
from tqdm.autonotebook import tqdm
from transformers import *
import numpy as np

# %%
def generate_text(
    input_ids, 
    tokenizer,
    output_filename,
    select_type='max', 
    n_symbols=1000, 
    max_frequency=200,
):

    for i in tqdm(range(n_symbols)):
        input_ids.insert(len(input_ids) - 1, tokenizer.mask_token_id)
        input_batch = torch.tensor(input_ids[i:]).to(torch.long).unsqueeze(0)
        with torch.no_grad():
            res = model(input_batch)[0]
        prob = torch.nn.functional.softmax(res, dim=-1)
        new_ids = None
        # Выбор самого вероятного слова
        if select_type == 'max': 
            new_ids = prob.max(-1)[1][0]
        # Выбор "медианного слова"
        elif select_type == 'median':
            new_ids = prob.median(-1)[1][0]
        # Выбор случайного из max_frequency слов
        elif select_type == 'random':
            new_ids = torch.topk(prob, max_frequency)[1][0][:,np.random.randint(0, max_frequency)]
        else:
            print("Wrong select_type")
            return None
        input_ids[len(input_ids) - 2] = new_ids.numpy()[len(input_ids[i:]) - 2]
    
    with open(output_filename, "w", encoding="utf-8") as output_file:
      output_file.write(tokenizer.decode(input_ids))

    return tokenizer.decode(input_ids)

# %%
MODEL = (MobileBertForMaskedLM, MobileBertTokenizer, 'google/mobilebert-uncased')

model_class, tokenizer_class, pretrained_weights = MODEL
# Load pretrained model/tokenizer
tokenizer = tokenizer_class.from_pretrained(pretrained_weights)
model = model_class.from_pretrained(pretrained_weights)
# Out:
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# loading file vocab.txt from cache at /root/.cache/huggingface/hub/models--google--mobilebert-uncased/snapshots/1f90a6c24c7879273a291d34a849033eba2dbc0f/vocab.txt
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at None
# loading file tokenizer_config.json from cache at None
# Downloading:   0%|          | 0.00/847 [00:00<?, ?B/s]
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--google--mobilebert-uncased/snapshots/1f90a6c24c7879273a291d34a849033eba2dbc0f/config.json
# Model config MobileBertConfig {
#   "_name_or_path": "google/mobilebert-uncased",
#   "architectures": [
#     "MobileBertForPreTraining"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_activation": false,
#   "classifier_dropout": null,
#   "embedding_size": 128,
#   "hidden_act": "relu",
#   "hidden_dropout_prob": 0.0,
#   "hidden_size": 512,
#   "initializer_range": 0.02,
#   "intermediate_size": 512,
#   "intra_bottleneck_size": 128,
#   "key_query_shared_bottleneck": true,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "mobilebert",
#   "normalization_type": "no_norm",
#   "num_attention_heads": 4,
#   "num_feedforward_networks": 4,
#   "num_hidden_layers": 24,
#   "pad_token_id": 0,
#   "transformers_version": "4.24.0",
#   "trigram_input": true,
#   "true_hidden_size": 128,
#   "type_vocab_size": 2,
#   "use_bottleneck": true,
#   "use_bottleneck_attention": false,
#   "vocab_size": 30522
# }
#
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--google--mobilebert-uncased/snapshots/1f90a6c24c7879273a291d34a849033eba2dbc0f/config.json
# Model config MobileBertConfig {
#   "_name_or_path": "google/mobilebert-uncased",
#   "architectures": [
#     "MobileBertForPreTraining"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_activation": false,
#   "classifier_dropout": null,
#   "embedding_size": 128,
#   "hidden_act": "relu",
#   "hidden_dropout_prob": 0.0,
#   "hidden_size": 512,
#   "initializer_range": 0.02,
#   "intermediate_size": 512,
#   "intra_bottleneck_size": 128,
#   "key_query_shared_bottleneck": true,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "mobilebert",
#   "normalization_type": "no_norm",
#   "num_attention_heads": 4,
#   "num_feedforward_networks": 4,
#   "num_hidden_layers": 24,
#   "pad_token_id": 0,
#   "transformers_version": "4.24.0",
#   "trigram_input": true,
#   "true_hidden_size": 128,
#   "type_vocab_size": 2,
#   "use_bottleneck": true,
#   "use_bottleneck_attention": false,
#   "vocab_size": 30522
# }
# Downloading:   0%|          | 0.00/147M [00:00<?, ?B/s]
# loading weights file pytorch_model.bin from cache at /root/.cache/huggingface/hub/models--google--mobilebert-uncased/snapshots/1f90a6c24c7879273a291d34a849033eba2dbc0f/pytorch_model.bin
# Some weights of the model checkpoint at google/mobilebert-uncased were not used when initializing MobileBertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing MobileBertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing MobileBertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of MobileBertForMaskedLM were initialized from the model checkpoint at google/mobilebert-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use MobileBertForMaskedLM for predictions without further training.

# %%
input_ids = tokenizer.encode("Here is some text to encode", add_special_tokens=True)  # Add special tokens takes care of adding [CLS], [SEP], <s>... tokens in the right way for each model.
print(input_ids)
# Out:
# [101, 2182, 2003, 2070, 3793, 2000, 4372, 16044, 102]

# %%
tokenizer.decode(input_ids)
# Out:
# '[CLS] here is some text to encode [SEP]'

# %%
input_ids[4] = tokenizer.mask_token_id
tokenizer.decode(input_ids)
# Out:
# '[CLS] here is some [MASK] to encode [SEP]'

# %%
input_batch = torch.tensor(input_ids).unsqueeze(0) # batch_size 1
with torch.no_grad():
    res = model(input_batch)[0]

# %%
prob = torch.nn.functional.softmax(res, dim=-1)
new_ids = prob.max(-1)[1]

# %%
tokenizer.decode(new_ids.numpy()[0, :].tolist())
# Out:
# '. here is some way to encode the'

# %%
GPT_TEXTS = [
    "In a shocking finding, scientist discovered a herd of unicorns living in a remote, previously unexplored valley, in the Andes Mountains. Even more surprising to the researchers was the fact that the unicorns spoke perfect English.",
    "A train carriage containing controlled nuclear materials was stolen in Cincinnati today. Its whereabouts are unknown."
    ]

# %% [markdown]
# Ваша задача - сгенерировать продолжение текстов, на которых демонстрировалась работа GPT-2 с помощью загруженной модели (DistillBERT). Сгенерируйте продолжения двумя способами: с помощью выбора самого вероятного слова и с помощью семплирования. Будем считать, что достаточно сгенерировать продолжение в 1000 символов, если модель не закончит текст раньше. Также можно попробовать сравнить эту генерацию с какой-нибудь легковесной gpt, например, "sshleifer/tiny-gpt2".

# %% [markdown]
# # Выбор самого вероятного слова

# %%
input_ids = tokenizer.encode(GPT_TEXTS[0], add_special_tokens=True)
generated_text_1 = generate_text(input_ids, tokenizer, output_filename="generated_text_1.txt", select_type='max', n_symbols=1000)

input_ids = tokenizer.encode(GPT_TEXTS[1], add_special_tokens=True)
generated_text_2 = generate_text(input_ids, tokenizer, output_filename="generated_text_2.txt", select_type='max', n_symbols=1000)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
# !cat generated_text_1.txt
# Out:
# [CLS] in a shocking finding, scientist discovered a herd of unicorns living in a remote, previously unexplored valley, in the andes mountains. even more surprising to the researchers was the fact that the unicorns spoke perfect english. "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... [SEP]

# %%
# !cat generated_text_2.txt
# Out:
# [CLS] a train carriage containing controlled nuclear materials was stolen in cincinnati today. its whereabouts are unknown. "......... "............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................. [SEP]

# %% [markdown]
# По всей видимости, слово с максмимальной вероятностью не дало видимого эффекта

# %% [markdown]
# # Выбор "медианного" слова

# %%
input_ids = tokenizer.encode(GPT_TEXTS[0], add_special_tokens=True)
generated_text_3 = generate_text(input_ids, tokenizer, output_filename="generated_text_3.txt", select_type='median', n_symbols=1000)

input_ids = tokenizer.encode(GPT_TEXTS[1], add_special_tokens=True)
generated_text_4 = generate_text(input_ids, tokenizer, output_filename="generated_text_4.txt", select_type='median', n_symbols=1000)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
# !cat generated_text_3.txt

# %%
# !cat generated_text_4.txt

# %% [markdown]
# # Выбор слова из набора N случайных

# %%
input_ids = tokenizer.encode(GPT_TEXTS[0], add_special_tokens=True)
generated_text_5 = generate_text(input_ids, tokenizer, output_filename="generated_text_5_1.txt", select_type='random', n_symbols=1000, max_frequency=200)

input_ids = tokenizer.encode(GPT_TEXTS[0], add_special_tokens=True)
generated_text_5_1 = generate_text(input_ids, tokenizer, output_filename="generated_text_5_1.txt", select_type='random', n_symbols=1000, max_frequency=150)

input_ids = tokenizer.encode(GPT_TEXTS[1], add_special_tokens=True)
generated_text_6 = generate_text(input_ids, tokenizer, output_filename="generated_text_6_1.txt", select_type='random', n_symbols=1000, max_frequency=200)

input_ids = tokenizer.encode(GPT_TEXTS[1], add_special_tokens=True)
generated_text_6_1 = generate_text(input_ids, tokenizer, output_filename="generated_text_6_2.txt", select_type='random', n_symbols=1000, max_frequency=150)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# [CLS] in a shocking finding, scientist discovered a herd of unicorns living in a remote, previously unexplored valley, in the andes mountains. even more surprising to the researchers was the fact that the unicorns spoke perfect english. john stewart came downstairs came quietly mounted below just dead heved king headsing mounted seated closer under more grass removed sir edward gordon then told morrisons let seem last outside one all street lay was well yesterday let pause downe addressers begin party yesterday below you said landforst the all day'wherehead club laid finished … behind rules commenceness he wait be part longer stop monday mother christmas ‘ goodbye baby tonight girl enough no what ready match sleep dreaming be call their circle should something been is used play fine ‘ kicking live mayow ball dance down early mix hard 2 this ) push rhythm speed bitch live star racer energy drum revolution + i more commitment hold cause impact will complete % reign let die so soft remain faithful shine also with end and continues ambition best mark where rest lose after an age from line strike away continue battle wins run rest behind lose her treasure battle 2016 won crossley point support home retreat defeated a bid remain good anchor pull ; search & turn stroke odds action grip battle travel * … proceed launch romance begins [UNK] spawn from other pools / replay off … make popular engagement procedure kill off? nothing fun & wicked switch tv session host number record pause test news mode online navigation feed archived date against reference date supplement album weekly service rental dvds tv challenge documentary edits trailer produced show poker plans + personalities unlimited profile + exclusive chart plus notes search session experience review result rest votes done votes met contestised motion fixed strings | algorithm & notes rules … chart edit scheme. animation ( review programme information survey it lists target table star spot – check — point } image files fixed theme profile class interface model overview caser response input comments target status in media community blogs the common format fashion concept development category friendly - services the application builder approach offering deals them brand designers across cloud details like windows621 tableserceancy website services dashboard studio devices / messages workshop forum space " architecture media servera startup industry innovation tools groupy deployment ( resources code status dashboard applications generic environments cloud technologies weather analysis elements interactions tracking missions activity etc what confusion | corruption analytics ratings department that services officer liaison! c stock summary event action analytics product reviews in collaboration teams engaged users ( facilities / agencies sharing in these profiles statistics other works, surveys, assessments taxes sales groups awards activity pools systems summary flows customer replies rating updates data in buildings organizations intelligence business engagement conferences process presentations conferences consultation modules management functions forums * requirements transactions definitions rules activity - risks publications accomplishments media technicalism in areas cases facts briefs formats support facts duties of subsidiaries analysts live networks " : pdf compression pages system pages api chapter abstracts folder text layer documents table contents citations citations data providers * stats information subjects unknown document detail handling access domains is described further be at down visit anodot include updates file collection visits also hosted needs calendar dataset library namemarks note lists ; key sheets graphical presentations format change views more places were checkeds individually allows feature ifets for production releases worldwide drive process options external types timeline parameters database current parts timeline processes attributes + comme ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# [CLS] a train carriage containing controlled nuclear materials was stolen in cincinnati today. its whereabouts are unknown. crash school board control file system section 46 % a facility area centralide west hospital which category ii bathroom plan treatment etcam areas was secured due 3 fatalities! surgery attached into locationed care ii s [UNK] 生 surgery required given 8 them? ii adjitakwmy my god when … thou saw wicked beloved aless this song while another child born through die wicked countryheart joy “ c legend king david archer gold ball dicedle punch line winner 9 " london : 1996 launch arcade " racing table results round from others challenges 1996 start 21 32 to 0 5000 experience 2004 competition singles contestants winners start loss 2009 1 lot 2008 2002 disqualification practice rage vote # 52 cast two wins broadcast disaster warning cut power shock transmission squad shock reset combo range event explosion popcu fighter series flight warning response signal link flare box activation surprise traumacomone delivery automaticization rounds over test theater display counters device points production values products scores solutions approaches sources providesrs lessons domains communication shows on data domains observations challenges observations approach and activities environment risks subjects education seminars planning business solution cooperation comparison groups online topics books engagement strategies industry details guidance design administration feedbackability conditions resources education storage operations strategies administration advancement support status plan consulting configuration further level creationity and convenience the customer acquisition group contents overview address recommendation call interface request feedback with knowledge requirements via frequency source technology functionality effects requirements communication update strategy guidelines projects partnership relationships programming excellence technologies branding schedules launches and initiatives standards organizations behavior professional programs conductide devices conferences companies public health scores promotions judges assemblies in company member life group guides publications association sessions topics awards medals participation celebration occasions studies visit to board assignment responsibilities committees action book reports guidance centers videos media study tours journals assessments researches challenges conditions program trials networks programming tests requirements budgets control theory charts promotions education online conservation progress agencies governance campaigns cooperation alliances media ownership practices funds awards tools " tools development groups network that friends worldwide supports project providers provided systems software revenues assistance issues organisations response screens feedback chains tools on call sharing accessibility portals they include'channels be meing itself within door chains communication application distribution software code platform release monitoring schedules communications systems transport movement systems progress implementation models functions in addition traffic it can control related reports currently events based outputs – in response functions provides demand utility staff signals deliver traffic orders but so common loads assigned – staff communications response experience update systems learned / resources commander train news support aviation warc automotive magazine? / am typexz commarcor2 train connect and feed network connect premium system discount care telephone etchering computer entry interface panels card change connectivity hubnet connections sites panels embedded machines connect management query plates activation : icon® impact module tracking relay interfaces podium tiles background wear tasks switching cards processes progress performance programming + a™20 standard ) draw artwork display " image analysis — class che ...

# %%
# !cat generated_text_5_1.txt

# %%
# !cat generated_text_5_2.txt

# %%
# !cat generated_text_6_1.txt

# %%
# !cat generated_text_6_2.txt
